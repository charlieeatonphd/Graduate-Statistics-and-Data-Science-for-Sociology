// %%
use data/hd_sfa_2022, clear
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>

// %%
drop if control==-3
// Out:
// (30 observations deleted)

// %%
graph bar loan_a, over(control) scheme(dubois)
